# %% [markdown]
# # Mentoría 'de cómo clasificar en géneros a las canciones'
# ## Práctico III : Introducción al aprendizaje automático

# %% [markdown]
# ### Librerías

# %%
# ESTA CELDA SOLO PARA COLAB
#!pip3 install spotipy
#!pip3 install pandas

# Agregar las librerías extra que se utilicen en esta celda y la siguiente

# %% [markdown]
# ### Dependencias y acceso al API

# %%
import pandas as pd
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = '46b333d567314a89a6254b6c6b054be6'
client_secret = '9d922c3613e441518349dcf55f7d5853'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### 1) Recopilar los datos obtenidos en los prácticos anteriores
#
# Para esta parte consideraremos [la playlist colaborativa de la mentoría](https://open.spotify.com/playlist/2IuD0qZb14cji5y52crdsO?si=nfHRPDquQRyotEcXc4tG7Q), de esta obtendremos:
# - Las features del audio de las canciones
# - Las features textuales de sus letras
#
# Además es necesario aplicar el mismo preprocesamiento que aplicamos en los prácticos anteriores para ambos tipos de features (el preprocesamiento del p1 a las features de audio y el de p2 al de features textuales) y obtener el género de cada canción, que en caso de ser más de uno para una canción el equipo deberá discutir una estrategia para estos casos y comentarla en el informe.
#
# Luego, se separará al dataset resultante en **X** e **y**, donde:
# - X es el conjunto de features
# - y es la etiqueta, en este caso el género de la canción, que deberá ser codificado en valores del tipo **int**
#
# Por último, se dividirá a estos dos conjuntos en los splits **train** y **test**
#
# **Recomendaciones:**
# - Obtener las features por separado y hacer un join de los datasets.
# - Prestar atención a la [documentación de sklearn](https://scikit-learn.org/stable/)
# - Si usan features categóricas, ENCODEARLAS!

# %%
dic_features = sp.audio_features('spotify:track:480dDrqG7LO6qDaphHeXlM')
my_features = list(dic_features[0])+['num_artists', 'track_name', 'genero', 'artist_name']

results = sp.playlist_tracks(playlist_id='spotify:playlist:2IuD0qZb14cji5y52crdsO')
items = results['items']
while results['next']:
    results = sp.next(results)
    items.extend(results['items'])

# %%
df = pd.DataFrame(columns=my_features)
i=0
len_items = len(items)
for item in items:
    track_uri = item['track']['uri']
    track_artists = item['track']['artists'] 
    my_row = sp.audio_features(track_uri)[0]
    my_row['num_artists'] = len(track_artists)
    artist = sp.artist(item['track']['artists'][0]['uri'])
    my_row['track_name'] = item['track']['name']
    my_row['genero'] = artist['genres']
    my_row['artist_name'] = artist['name']
    df = df.append(my_row, ignore_index=True)
    i+=1
    print(str(i) + ' de ' + str(len_items) + '\r', end='')
df
# Out:
# 1188 de 1188
#       danceability  energy key  loudness mode  speechiness  acousticness  \
# 0            0.161   0.482   1   -11.210    0       0.0472        0.4860
# 1            0.230   0.434  10   -12.402    0       0.0551        0.5700
# 2            0.289   0.280   9   -15.335    1       0.0433        0.8740
# 3            0.499   0.648   7    -5.812    1       0.0331        0.7230
# 4            0.528   0.383   2   -11.170    1       0.0258        0.3760
# ...            ...     ...  ..       ...  ...          ...           ...
# 1183         0.714   0.753   7    -9.023    1       0.0309        0.0144
# 1184         0.408   0.828   7    -6.222    1       0.0622        0.7400
# 1185         0.684   0.802   5    -6.619    0       0.0391        0.2360
# 1186         0.541   0.734   4    -7.516    0       0.2240        0.5410
# 1187         0.600   0.897   7    -5.833    1       0.0470        0.1570
#
#       instrumentalness  liveness  valence  ...                      id  \
# 0             0.409000     0.371   0.0926  ...  7j9DYPyCuvSAtPcevpAkzb
# 1             0.000000     0.115   0.0834  ...  1cwTMSQeMaA9fVKEF1iWeD
# 2             0.004430     0.124   0.0391  ...  0aL27vskbMpwsMGUkHm3Zf
# 3             0.000000     0.576   0.4640  ...  2kfSFdq2h0xLXq01em1zc7
# 4             0.000000     0.110   0.4600  ...  5ySxlyvySBhIEvoO2xx7uT
# ...                ...       ...      ...  ...                     ...
# 1183          0.000003     0.325   0.9100  ...  3TkZFF0JOcc8QXQyxqLB5J
# 1184          0.000000     0.322   0.4680  ...  76DYAASchu5szMWFDuG1iP
# 1185          0.000012     0.438   0.8390  ...  1o7e4Tadn4o6nPvycwIP0C
# 1186          0.000000     0.382   0.7040  ...  5AZwGCyE9tIzFYXpqyrKHm
# 1187          0.000610     0.877   0.7560  ...  6Lkh9lukUEPBTZ1gewNT0m
#
#                                        uri  \
# 0     spotify:track:7j9DYPyCuvSAtPcevpAkzb
# 1     spotify:track:1cwTMSQeMaA9fVKEF1iWeD
# 2     spotify:track:0aL27vskbMpwsMGUkHm3Zf
# 3     spotify:track:2kfSFdq2h0xLXq01em1zc7
# 4     spotify:track:5ySxlyvySBhIEvoO2xx7uT
# ...                                    ...
# 1183  spotify:track:3TkZFF0JOcc8QXQyxqLB5J
# 1184  spotify:track:76DYAASchu5szMWFDuG1iP
# 1185  spotify:track:1o7e4Tadn4o6nPvycwIP0C
# 1186  spotify:track:5AZwGCyE9tIzFYXpqyrKHm
# 1187  spotify:track:6Lkh9lukUEPBTZ1gewNT0m
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7j9DYPyCuvSA...
# 1     https://api.spotify.com/v1/tracks/1cwTMSQeMaA9...
# 2     https://api.spotify.com/v1/tracks/0aL27vskbMpw...
# 3     https://api.spotify.com/v1/tracks/2kfSFdq2h0xL...
# 4     https://api.spotify.com/v1/tracks/5ySxlyvySBhI...
# ...                                                 ...
# 1183  https://api.spotify.com/v1/tracks/3TkZFF0JOcc8...
# 1184  https://api.spotify.com/v1/tracks/76DYAASchu5s...
# 1185  https://api.spotify.com/v1/tracks/1o7e4Tadn4o6...
# 1186  https://api.spotify.com/v1/tracks/5AZwGCyE9tIz...
# 1187  https://api.spotify.com/v1/tracks/6Lkh9lukUEPB...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7j9D...      233079
# 1     https://api.spotify.com/v1/audio-analysis/1cwT...      216905
# 2     https://api.spotify.com/v1/audio-analysis/0aL2...      215773
# 3     https://api.spotify.com/v1/audio-analysis/2kfS...      219107
# 4     https://api.spotify.com/v1/audio-analysis/5ySx...      328320
# ...                                                 ...         ...
# 1183  https://api.spotify.com/v1/audio-analysis/3TkZ...      202333
# 1184  https://api.spotify.com/v1/audio-analysis/76DY...      330493
# 1185  https://api.spotify.com/v1/audio-analysis/1o7e...      260533
# 1186  https://api.spotify.com/v1/audio-analysis/5AZw...      250013
# 1187  https://api.spotify.com/v1/audio-analysis/6Lkh...      259587
#
#      time_signature num_artists              track_name  \
# 0                 5           1                 Desafío
# 1                 5           1                  Anoche
# 2                 3           1               Sin Rumbo
# 3                 4           1  La Gata Bajo la Lluvia
# 4                 4           1                 Querida
# ...             ...         ...                     ...
# 1183              4           1             El Divorcio
# 1184              4           1      Tema de "cabecita"
# 1185              4           1             En Libertad
# 1186              4           1    Amante Tu, Amante El
# 1187              4           1      Todo Me Lleva a Ti
#
#                                                  genero   artist_name
# 0     [art pop, dance pop, deconstructed club, elect...          Arca
# 1     [art pop, dance pop, deconstructed club, elect...          Arca
# 2     [art pop, dance pop, deconstructed club, elect...          Arca
# 3     [bolero, cancion melodica, grupera, latin, lat...  Rocío Dúrcal
# 4                  [cancion melodica, latin, latin pop]  Juan Gabriel
# ...                                                 ...           ...
# 1183  [argentine rock, cuarteto, cumbia pop, cumbia ...       Rodrigo
# 1184  [argentine rock, cuarteto, cumbia pop, cumbia ...       Rodrigo
# 1185  [argentine rock, cuarteto, cumbia pop, cumbia ...       Rodrigo
# 1186  [argentine rock, cuarteto, cumbia pop, cumbia ...       Rodrigo
# 1187  [argentine rock, cuarteto, cumbia pop, cumbia ...       Rodrigo
#
# [1188 rows x 22 columns]

# %%
#Hay tracks asociados a mas de un artista, por defecto el dataframe tomó el primer artista que figure en la lista
df[df['num_artists'] > 1]
# Out:
#       danceability  energy key  loudness mode  speechiness  acousticness  \
# 83           0.679   0.630   7    -6.207    0       0.0283       0.11100
# 84           0.659   0.870   7    -5.216    1       0.0872       0.29000
# 85           0.457   0.773   2    -6.957    1       0.2330       0.45300
# 86           0.529   0.830   9    -5.835    0       0.0685       0.08300
# 91           0.669   0.879  11    -5.968    1       0.0977       0.28100
# ...            ...     ...  ..       ...  ...          ...           ...
# 1132         0.943   0.621  10    -2.603    0       0.0555       0.10700
# 1134         0.864   0.813   7    -4.484    1       0.0620       0.24600
# 1135         0.723   0.833   9    -4.677    0       0.0334       0.39600
# 1137         0.530   0.918   0    -4.486    1       0.0575       0.00102
# 1138         0.498   0.914   4    -2.723    0       0.0761       0.16900
#
#       instrumentalness  liveness  valence  ...                      id  \
# 83            0.000000    0.0423    0.711  ...  20aVSAxv2YvRHYlB4kk1E5
# 84            0.000000    0.2130    0.633  ...  4g4iKJ37XZrOVSNzEqI1PE
# 85            0.000000    0.7290    0.402  ...  1ql24CwT4y5pZjAJRhpY5a
# 86            0.000000    0.9320    0.748  ...  1QZ5uqBDf91CsilGfbdV1H
# 91            0.000000    0.1500    0.657  ...  0vV3UvotpuHNC3mmKbUpSS
# ...                ...       ...      ...  ...                     ...
# 1132          0.000112    0.3390    0.963  ...  2d7D5eOzALYwuSJUs7WqEH
# 1134          0.001810    0.0330    0.794  ...  3RxFQSlNXtcH3gVlAsCRhE
# 1135          0.000007    0.1760    0.925  ...  1WKMdjbER963jNYHB3Jrfg
# 1137          0.000128    0.6890    0.483  ...  1e4PRJWfSorO7RLgqDRvYR
# 1138          0.000000    0.4560    0.483  ...  6HxBuCzeutRKZOBb9My8XT
#
#                                        uri  \
# 83    spotify:track:20aVSAxv2YvRHYlB4kk1E5
# 84    spotify:track:4g4iKJ37XZrOVSNzEqI1PE
# 85    spotify:track:1ql24CwT4y5pZjAJRhpY5a
# 86    spotify:track:1QZ5uqBDf91CsilGfbdV1H
# 91    spotify:track:0vV3UvotpuHNC3mmKbUpSS
# ...                                    ...
# 1132  spotify:track:2d7D5eOzALYwuSJUs7WqEH
# 1134  spotify:track:3RxFQSlNXtcH3gVlAsCRhE
# 1135  spotify:track:1WKMdjbER963jNYHB3Jrfg
# 1137  spotify:track:1e4PRJWfSorO7RLgqDRvYR
# 1138  spotify:track:6HxBuCzeutRKZOBb9My8XT
#
#                                              track_href  \
# 83    https://api.spotify.com/v1/tracks/20aVSAxv2YvR...
# 84    https://api.spotify.com/v1/tracks/4g4iKJ37XZrO...
# 85    https://api.spotify.com/v1/tracks/1ql24CwT4y5p...
# 86    https://api.spotify.com/v1/tracks/1QZ5uqBDf91C...
# 91    https://api.spotify.com/v1/tracks/0vV3UvotpuHN...
# ...                                                 ...
# 1132  https://api.spotify.com/v1/tracks/2d7D5eOzALYw...
# 1134  https://api.spotify.com/v1/tracks/3RxFQSlNXtcH...
# 1135  https://api.spotify.com/v1/tracks/1WKMdjbER963...
# 1137  https://api.spotify.com/v1/tracks/1e4PRJWfSorO...
# 1138  https://api.spotify.com/v1/tracks/6HxBuCzeutRK...
#
#                                            analysis_url duration_ms  \
# 83    https://api.spotify.com/v1/audio-analysis/20aV...      270146
# 84    https://api.spotify.com/v1/audio-analysis/4g4i...      184360
# 85    https://api.spotify.com/v1/audio-analysis/1ql2...      272640
# 86    https://api.spotify.com/v1/audio-analysis/1QZ5...      222000
# 91    https://api.spotify.com/v1/audio-analysis/0vV3...      303253
# ...                                                 ...         ...
# 1132  https://api.spotify.com/v1/audio-analysis/2d7D...      199560
# 1134  https://api.spotify.com/v1/audio-analysis/3RxF...     1047973
# 1135  https://api.spotify.com/v1/audio-analysis/1WKM...      208067
# 1137  https://api.spotify.com/v1/audio-analysis/1e4P...      257808
# 1138  https://api.spotify.com/v1/audio-analysis/6HxB...      242051
#
#      time_signature num_artists                         track_name  \
# 83                4           3                 Y se murió de amor
# 84                4           2                          Ese guaso
# 85                4           3                            Solo tú
# 86                4           3                     Mujer y amante
# 91                4           3                        Beso a beso
# ...             ...         ...                                ...
# 1132              4           3                         Vete de Mi
# 1134              4          10                    Batalla Villera
# 1135              4          11             Amores Como el Nuestro
# 1137              4           2                      Me Extrañarás
# 1138              4           2  Lo Mejor del Amor (Remasterizado)
#
#                                                  genero      artist_name
# 83                                           [cuarteto]  La Mona Jimenez
# 84                                           [cuarteto]  La Mona Jimenez
# 85                                           [cuarteto]  La Mona Jimenez
# 86                                           [cuarteto]  La Mona Jimenez
# 91                                           [cuarteto]  La Mona Jimenez
# ...                                                 ...              ...
# 1132                                   [cumbia villera]     Damas Gratis
# 1134                                   [cumbia villera]     Eh!!! Guacho
# 1135                          [chamame, cumbia villera]   Daniel Cardozo
# 1137  [argentine rock, cuarteto, cumbia pop, cumbia ...          Rodrigo
# 1138  [argentine rock, cuarteto, cumbia pop, cumbia ...          Rodrigo
#
# [158 rows x 22 columns]

# %%
#Borramos features que no se utilizaran
df.drop(columns=['track_href', 'analysis_url', 'type'], inplace=True)

# %%
#Se pasa el feature "mode" a int
df['mode'] = df['mode'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188 entries, 0 to 1187
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      1188 non-null   float64
#  1   energy            1188 non-null   float64
#  2   key               1188 non-null   object
#  3   loudness          1188 non-null   float64
#  4   mode              1188 non-null   int32
#  5   speechiness       1188 non-null   float64
#  6   acousticness      1188 non-null   float64
#  7   instrumentalness  1188 non-null   float64
#  8   liveness          1188 non-null   float64
#  9   valence           1188 non-null   float64
#  10  tempo             1188 non-null   float64
#  11  id                1188 non-null   object
#  12  uri               1188 non-null   object
#  13  duration_ms       1188 non-null   object
#  14  time_signature    1188 non-null   object
#  15  num_artists       1188 non-null   object
#  16  track_name        1188 non-null   object
#  17  genero            1188 non-null   object
#  18  artist_name       1188 non-null   object
# dtypes: float64(9), int32(1), object(9)
# memory usage: 171.8+ KB

# %%
df.describe()
# Out:
#        danceability       energy     loudness         mode  speechiness  \
# count   1188.000000  1188.000000  1188.000000  1188.000000  1188.000000
# mean       0.584945     0.719107    -6.441112     0.608586     0.069333
# std        0.152793     0.182300     2.780900     0.488272     0.066591
# min        0.148000     0.108000   -19.575000     0.000000     0.022600
# 25%        0.488000     0.604000    -7.732000     0.000000     0.032475
# 50%        0.602000     0.751000    -6.033500     1.000000     0.043600
# 75%        0.696250     0.866000    -4.540000     1.000000     0.075050
# max        0.945000     0.995000    -0.767000     1.000000     0.514000
#
#        acousticness  instrumentalness     liveness      valence        tempo
# count   1188.000000       1188.000000  1188.000000  1188.000000  1188.000000
# mean       0.221064          0.019832     0.245267     0.603119   124.744035
# std        0.233256          0.104347     0.235297     0.228579    30.074290
# min        0.000002          0.000000     0.027700     0.037700    62.850000
# 25%        0.033975          0.000000     0.096650     0.420750    97.031750
# 50%        0.137000          0.000002     0.142000     0.620500   125.002500
# 75%        0.341000          0.000225     0.307250     0.794000   147.262750
# max        0.982000          0.944000     0.991000     0.976000   204.498000

# %%
df.to_csv('practico3_audio_features.csv', index=False)
